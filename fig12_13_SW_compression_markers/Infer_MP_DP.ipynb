# %%
from scipy.io import readsav


#import datetime as dt

#import matplotlib.patches
#import matplotlib.pyplot as plt
#import numpy as np
#import pandas as pd
#import math

# %%
DP_file = '../data/raw/crossings_inferred_DP.sav'

inferred_DP_vals=readsav(DP_file)

print(inferred_DP_vals)
#;Also plot the Kanani model magnetopause
##  a1=10.3
##  a2=0.2
#  a3=0.73
#  a4=0.4

#  Dp1=0.1  ;in nPa
#  r01=a1*Dp1^(-a2)
#  k1=a3+a4*Dp1
    
#     ;theta varies between 0 and pi (or 0.5 and 179.5 degrees). Must get cos of value in radians though
#  theta=((indgen(1800))/10.)*!dtor
#  theta(0) = 0.0001  ;to avoid dividing by 0!
  
#;  r1=r01 * (2./(1. + cos(theta))^k1)  ;incorrect bracket placement
#  r1=r01 * ((2./(1. + cos(theta)))^k1)  ;correct bracket placement [fixed November 9th 2018]

  
#  x1=r1*cos(theta)
#  rho1 = abs(x1*tan(theta))
# Out:
# {'dp_mp_kanani': array([0.        , 0.        , 0.        , ..., 0.05307163, 0.15743401,
#        0.24728434], dtype='>f8'), 'dp_bs_went': array([0.0076546 , 0.00789858, 0.01128036, ..., 0.        , 0.        ,
#        0.        ], dtype='>f8'), 'inf_dp_mp_kanani_flag': array(['', '', '', ..., b'valid', b'valid', b'valid'], dtype=object), 'r_cross': array([49.19047512, 48.88893662, 45.58598151, ..., 18.85672174,
#        17.0577022 , 14.57710498], dtype='>f8'), 'theta_cross': array([1.09704715, 1.09642065, 1.08906957, ..., 0.31109263, 0.81327649,
#        0.57015868], dtype='>f8')}
