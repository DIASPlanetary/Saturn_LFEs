# %% [markdown]
# # Average and Median Spectrograms of Jupiter's Magnetic flux using over entire Cassini mission duration.

# %%
import numpy as np
import pandas as pd

import xarray as xr
from scipy.io import readsav

from tfcat import TFCat

import matplotlib.colors as mp_colors
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
def get_sav_data(year):
    """Select sav data for a chosen year.
    
    Parses through an SKR year file to obtain the time, frequency and flux data.
    
    Parameters
    ----------
    year: int or str
        Year of the file wanted.
    
    Returns
    -------
    time: numpy.array
        Time series in 3 minute step.

    freq: numpy.array
        Midpoint values of Cassini frequency bins.

    flux: numpy.array (freq.shape, time.shape)
        Magnetic flux values for the chosen year.
    """

    skr_raw_fp = '../data/raw/SKR_raw'

    file_skr = skr_raw_fp + f'/SKR_{year}_CJ.sav'
    raw_skr = readsav(file_skr)
    flux, time_doy, freq = raw_skr['s'].copy(), raw_skr['t'], raw_skr['f']
    flux[flux == 0] = np.nan  # replace 0 with nans

    time = (time_doy * 24 * 3600).astype('timedelta64[s]') + np.datetime64('1997') - np.timedelta64(1, 'D') + np.timedelta64(1, 's') # SAV time correction
    time = time.astype('datetime64[m]')
    time = time.astype('datetime64[s]')

    return time, freq, flux

# %%
ephemeris_fp = '../data/calculated/20040101000000_20170915115700_ephemeris.csv'

# %% [markdown]
# Read the polygon's masked flux

# %%
times, fluxes = [], []
for year in range(2004, 2018):
    time, _, flux = get_sav_data(year)

    times.append(time)
    fluxes.append(flux)

_, freq, _ = get_sav_data(2004)

freq = freq.astype(float)
time = np.concatenate(times, axis=0)
flux = np.concatenate(fluxes, axis=1)

# %% [markdown]
# Create a panda dataframe with frequency values as columns

# %%
df = pd.DataFrame(flux.T, columns=freq)
df['Universal Time'] = time
df
# Out:
#          3.9548  4.7729  5.7601  6.9516  8.3895  10.1248  12.2191  14.7465  \
# 0           NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 1           NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 2           NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 3           NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 4           NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# ...         ...     ...     ...     ...     ...      ...      ...      ...
# 2403355     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 2403356     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 2403357     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 2403358     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 2403359     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
#
#          17.796801  21.4779  ...  1100.0  1150.0  1200.0  1250.0  1300.0  \
# 0              NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1              NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2              NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN
# 3              NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN
# 4              NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN
# ...            ...      ...  ...     ...     ...     ...     ...     ...
# 2403355        NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2403356        NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2403357        NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2403358        NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2403359        NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN
#
#          1350.0  1400.0  1450.0  1500.0      Universal Time
# 0           NaN     NaN     NaN     NaN 2004-01-01 00:00:00
# 1           NaN     NaN     NaN     NaN 2004-01-01 00:03:00
# 2           NaN     NaN     NaN     NaN 2004-01-01 00:06:00
# 3           NaN     NaN     NaN     NaN 2004-01-01 00:09:00
# 4           NaN     NaN     NaN     NaN 2004-01-01 00:12:00
# ...         ...     ...     ...     ...                 ...
# 2403355     NaN     NaN     NaN     NaN 2017-09-15 23:45:00
# 2403356     NaN     NaN     NaN     NaN 2017-09-15 23:48:00
# 2403357     NaN     NaN     NaN     NaN 2017-09-15 23:51:00
# 2403358     NaN     NaN     NaN     NaN 2017-09-15 23:54:00
# 2403359     NaN     NaN     NaN     NaN 2017-09-15 23:57:00
#
# [2403360 rows x 49 columns]

# %% [markdown]
# Read the ephemeris data as a pandas dataframe

# %%
df_ephemeris = pd.read_csv(ephemeris_fp)
df_ephemeris = df_ephemeris.rename(columns={'start': 'Universal Time'})  # Rename datetime column to Universal Time
df_ephemeris["Universal Time"] = np.array(df_ephemeris['Universal Time'], dtype='datetime64')  # Convert strings to datetime64 format
df_ephemeris
# Out:
#          Unnamed: 0      Universal Time       x_ksm        y_ksm       z_ksm  \
# 0                 0 2004-01-01 00:00:00  664.545415 -1282.271820 -134.013894
# 1                 1 2004-01-01 00:01:00  664.542412 -1282.267682 -134.011330
# 2                 2 2004-01-01 00:02:00  664.539410 -1282.263543 -134.008771
# 3                 3 2004-01-01 00:03:00  664.536407 -1282.259404 -134.006218
# 4                 4 2004-01-01 00:04:00  664.533404 -1282.255265 -134.003670
# ...             ...                 ...         ...          ...         ...
# 7209352     7209352 2017-09-15 11:52:00   -0.092238     0.399237    0.032108
# 7209353     7209353 2017-09-15 11:53:00   -0.115321     0.401941    0.042341
# 7209354     7209354 2017-09-15 11:54:00   -0.138326     0.404378    0.052547
# 7209355     7209355 2017-09-15 11:55:00   -0.161239     0.406547    0.062719
# 7209356     7209356 2017-09-15 11:56:00   -0.184044     0.408446    0.072851
#
#             subLat      subLon    subLST        R_ksm
# 0       -19.815933   78.646614  7.525833  1450.448673
# 1       -19.815933   79.209665  7.525833  1450.443402
# 2       -19.815932   79.772716  7.525833  1450.438131
# 3       -19.815932   80.335768  7.525833  1450.432860
# 4       -19.815932   80.898819  7.525833  1450.427589
# ...            ...         ...       ...          ...
# 7209352   2.168796  157.198413  6.909167     0.411010
# 7209353   2.325404  154.503713  7.126389     0.420295
# 7209354   2.467676  151.956936  7.333611     0.430600
# 7209355   2.596060  149.561459  7.530833     0.441828
# 7209356   2.711243  147.317501  7.718056     0.453881
#
# [7209357 rows x 9 columns]

# %% [markdown]
# Merge both dataframes on their Universal time column

# %%
df_all = df.merge(df_ephemeris, on='Universal Time')

# %% [markdown]
# We can now bin the values with respect to local time (subLST column)

# %%
bins = np.arange(0, 24.2, 0.2)  # 0 to 24hr with an interval of 12 min
df_all['local_time'] = pd.cut(df_all['subLST'], bins=bins) # Create and add bin column to the entire dataframe
df_all
# Out:
#          3.9548  4.7729  5.7601  6.9516  8.3895  10.1248  12.2191  14.7465  \
# 0           NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 1           NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 2           NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 3           NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 4           NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# ...         ...     ...     ...     ...     ...      ...      ...      ...
# 2403114     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 2403115     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 2403116     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 2403117     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 2403118     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN
#
#          17.796801  21.4779  ...      Universal Time  Unnamed: 0       x_ksm  \
# 0              NaN      NaN  ... 2004-01-01 00:00:00           0  664.545415
# 1              NaN      NaN  ... 2004-01-01 00:03:00           3  664.536407
# 2              NaN      NaN  ... 2004-01-01 00:06:00           6  664.527398
# 3              NaN      NaN  ... 2004-01-01 00:09:00           9  664.518389
# 4              NaN      NaN  ... 2004-01-01 00:12:00          12  664.509381
# ...            ...      ...  ...                 ...         ...         ...
# 2403114        NaN      NaN  ... 2017-09-15 11:42:00     7209342    0.139428
# 2403115        NaN      NaN  ... 2017-09-15 11:45:00     7209345    0.070198
# 2403116        NaN      NaN  ... 2017-09-15 11:48:00     7209348    0.000552
# 2403117        NaN      NaN  ... 2017-09-15 11:51:00     7209351   -0.069095
# 2403118        NaN      NaN  ... 2017-09-15 11:54:00     7209354   -0.138326
#
#                y_ksm       z_ksm     subLat      subLon    subLST  \
# 0       -1282.271820 -134.013894 -19.815933   78.646614  7.525833
# 1       -1282.259404 -134.006218 -19.815932   80.335768  7.525833
# 2       -1282.246984 -133.998591 -19.815931   82.024922  7.525833
# 3       -1282.234557 -133.991020 -19.815930   83.714076  7.525833
# 4       -1282.222125 -133.983511 -19.815928   85.403231  7.525833
# ...              ...         ...        ...         ...       ...
# 2403114     0.358038   -0.070229   0.015129  188.760594  4.429722
# 2403115     0.373030   -0.039713   0.719633  179.076798  5.188056
# 2403116     0.385800   -0.008958   1.403289  169.250599  5.955556
# 2403117     0.396269    0.021855   1.997736  160.033934  6.682778
# 2403118     0.404378    0.052547   2.467676  151.956936  7.333611
#
#                R_ksm  local_time
# 0        1450.448673  (7.4, 7.6]
# 1        1450.432860  (7.4, 7.6]
# 2        1450.417048  (7.4, 7.6]
# 3        1450.401235  (7.4, 7.6]
# 4        1450.385423  (7.4, 7.6]
# ...              ...         ...
# 2403114     0.390594  (4.4, 4.6]
# 2403115     0.381650  (5.0, 5.2]
# 2403116     0.385904  (5.8, 6.0]
# 2403117     0.402841  (6.6, 6.8]
# 2403118     0.430600  (7.2, 7.4]
#
# [2403119 rows x 58 columns]

# %% [markdown]
# Group values by bins and take their mean/median per frequency per bin

# %%
df_mean = df_all.groupby('local_time').mean()
df_median = df_all.groupby('local_time').median()
# Out:
# /var/folders/j9/q8hqts053r57j7y11x4bv2_c0000gn/T/ipykernel_66442/1511130122.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_mean = df_all.groupby('local_time').mean()
# /var/folders/j9/q8hqts053r57j7y11x4bv2_c0000gn/T/ipykernel_66442/1511130122.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_median = df_all.groupby('local_time').median()

# %% [markdown]
# The first 48 columns are all the frequency-flux values

# %%
mean_flux = df_mean.iloc[:, :48].to_numpy()
median_flux = df_median.iloc[:, :48].to_numpy()

# %% [markdown]
# Plots

# %%
fig = plt.figure(figsize=(10,5), dpi=100)
ax = fig.add_subplot()

norm = mp_colors.LogNorm(vmin=1e-22, vmax=1e-19)
cbar = ax.pcolormesh(bins[:-1], freq, mean_flux.T, norm=norm, cmap='plasma')

fig.colorbar(cbar, label=r'Flux [Log($W.m^{-2}.Hz^{-1}$)]', extend='both')

ax.set_xticks(bins[:-1:10])
ax.set_xticks(bins[:-1], minor=True)
ax.xaxis.set_major_formatter('{x:.0f}:00')

ax.set_yscale('log')
ax.set_xlabel('Local Time [hr]')
ax.set_ylabel('Frequency [kHz]');
#ax.set_title('Polygon-selected Mean Magnetic Flux per frequency channel per local time over entire Cassini duration');

# %%
fig = plt.figure(figsize=(10,5), dpi=100)
ax = fig.add_subplot()

norm = mp_colors.LogNorm()
cbar = ax.pcolormesh(bins[:-1], freq, median_flux.T, norm=norm, cmap='plasma')

fig.colorbar(cbar, label=r'Flux [Log($W.m^{-2}.Hz^{-1}$)]')

ax.set_xticks(bins[:-1:10])
ax.set_xticks(bins[:-1], minor=True)
ax.xaxis.set_major_formatter('{x:.0f}:00')

ax.set_yscale('log')
ax.set_xlabel('Local Time [hr]')
ax.set_ylabel('Frequency [kHz]');
#ax.set_title('Polygon-selected Median Magnetic Flux per frequency channel per local time over entire Cassini duration');
